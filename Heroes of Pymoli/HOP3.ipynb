# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
pd_df = pd.DataFrame(purchase_data)
pd_df.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %% [markdown]
# ## Gender Demographics

# %%
sn_count= pd_df["SN"].value_counts()
sn_count
# Out:
# Lisosia93        5
# Iral74           4
# Idastidru52      4
# Chadolyla44      3
# Inguron55        3
#                 ..
# Lirtirra81       1
# Frichjaskan98    1
# Sastydeu50       1
# Yana46           1
# Phaedasurap84    1
# Name: SN, Length: 576, dtype: int64

# %%
player_count = len(sn_count)

# %%
player_count_df = pd.DataFrame({"Total Number of Players": [player_count]})
player_count_df
# Out:
#    Total Number of Players
# 0                      576

# %%
unique_players = pd_df.drop_duplicates("SN")
unique_players
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male      101
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
item_count = pd_df["Item Name"].count()
item_count
# Out:
# 780

# %%
avg_price = pd_df["Price"].mean()
avg_price
# Out:
# 3.050987179487176

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
unique_items = len(pd_df["Item Name"].unique())
unique_items
# Out:
# 179

# %%
tot_rev = pd_df["Price"].sum()
tot_rev
# Out:
# 2379.77

# %%
pa_summary = pd.DataFrame([{"Number of Unique Items" :unique_items,
                            
                            "Average Price":avg_price,
                            
                            "Number of Purchases" : item_count,
                            
                            "Total Revenue" : tot_rev}])
pa_summary
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
pa_summary["Average Price"] = pa_summary["Average Price"].map("${:.2f}".format)
pa_summary["Total Revenue"] = pa_summary["Total Revenue"].map("${:,.2f}".format)
pa_summary
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
sales_by_gender = unique_players.groupby('Gender')
gender_count = sales_by_gender["Purchase ID"].count()
gender_count
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: Purchase ID, dtype: int64

# %%
gender_count_df = pd.DataFrame(gender_count)
gender_count_df
# Out:
#                        Purchase ID
# Gender
# Female                          81
# Male                           484
# Other / Non-Disclosed           11

# %%
gender_count_pct_df = (gender_count_df/576)*100
gender_count_pct_df
# Out:
#                        Purchase ID
# Gender
# Female                   14.062500
# Male                     84.027778
# Other / Non-Disclosed     1.909722

# %%
gender_count_df["Gender Percent"] = gender_count_pct_df
gender_count_df
# Out:
#                        Purchase ID  Gender Percent
# Gender
# Female                          81       14.062500
# Male                           484       84.027778
# Other / Non-Disclosed           11        1.909722

# %%
#https://www.geeksforgeeks.org/how-to-rename-columns-in-pandas-dataframe/
gender_count_df.rename(columns = {'Purchase ID':'Total Count'}, inplace = True)
gender_count_df
# Out:
#                        Total Count  Gender Percent
# Gender
# Female                          81       14.062500
# Male                           484       84.027778
# Other / Non-Disclosed           11        1.909722

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %%
gender_count_df["Gender Percent"] = gender_count_df["Gender Percent"].map("{:.2f}%".format)
gender_count_df
# Out:
#                        Total Count Gender Percent
# Gender
# Female                          81         14.06%
# Male                           484         84.03%
# Other / Non-Disclosed           11          1.91%

# %%
Gender_count_sort_df = gender_count_df.sort_values("Total Count",ascending=False)
Gender_count_sort_df
# Out:
#                        Total Count Gender Percent
# Gender
# Male                           484         84.03%
# Female                          81         14.06%
# Other / Non-Disclosed           11          1.91%

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
avgerage_sales=purchase_data.groupby('Gender')
avgerage_sales.first()
# Out:
#                        Purchase ID           SN  Age  Item ID  \
# Gender
# Female                          15    Lisassa64   21       98
# Male                             0      Lisim78   20      108
# Other / Non-Disclosed            9  Chanosian48   35      136
#
#                                                        Item Name  Price
# Gender
# Female                               Deadline, Voice Of Subtlety   2.89
# Male                   Extraction, Quickblade Of Trembling Hands   3.53
# Other / Non-Disclosed               Ghastly Adamantite Protector   3.58

# %%
sales_count = avgerage_sales["Purchase ID"].count()
sales_count
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Purchase ID, dtype: int64

# %%
avg_sales_gen = avgerage_sales["Price"].mean()
avg_sales_gen
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
tot_sales_gen = avgerage_sales["Price"].sum()
tot_sales_gen
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
avg_purch_tot_per = tot_sales_gen/gender_count
avg_purch_tot_per
# Out:
# Gender
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
purch_analysis_gender = pd.DataFrame({"Purchase Count":sales_count,
                                   "Average Purchase Price":avg_sales_gen, 
                                   "Total Purchase Value":tot_sales_gen, 
                                   "Avg Total Purchase per Person":avg_purch_tot_per})
purch_analysis_gender
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %%
purch_analysis_gender["Average Purchase Price"] = purch_analysis_gender["Average Purchase Price"].map("${:.2f}".format)
purch_analysis_gender["Total Purchase Value"] = purch_analysis_gender["Total Purchase Value"].map("${:.2f}".format)
purch_analysis_gender["Avg Total Purchase per Person"] = purch_analysis_gender["Avg Total Purchase per Person"].map("${:.2f}".format)
purch_analysis_gender
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9,50]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
age_data = purchase_data
age_data["Age Ranges"] = pd.cut(age_data["Age"], bins, labels=group_names)


age_demo_group = age_data.groupby("Age Ranges")

# Count players without repetitive names
age_count_demo = age_demo_group['SN'].nunique()
age_count_demo
# Out:
# Age Ranges
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
player_pct_demo = (age_count_demo/player_count)*100
player_pct_demo
# Out:
# Age Ranges
# <10       2.951389
# 10-14     3.819444
# 15-19    18.576389
# 20-24    44.791667
# 25-29    13.368056
# 30-34     9.027778
# 35-39     5.381944
# 40+       2.083333
# Name: SN, dtype: float64

# %%
age_demo_df = pd.DataFrame({"Total Count":age_count_demo, "Percentage of Players":player_pct_demo})
age_demo_df
# Out:
#             Total Count  Percentage of Players
# Age Ranges
# <10                  17               2.951389
# 10-14                22               3.819444
# 15-19               107              18.576389
# 20-24               258              44.791667
# 25-29                77              13.368056
# 30-34                52               9.027778
# 35-39                31               5.381944
# 40+                  12               2.083333

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data_grouped = age_data.groupby("Age Ranges") # df.groupby(['Item ID', 'Item Name'])
purchase_count_age = purchase_data_grouped["Purchase ID"].count()
#purchase_count_age
purchase_data_grouped.first()
# Out:
#             Purchase ID           SN  Age Gender  Item ID  \
# Age Ranges
# <10                  27      Eusri44    7   Male       96
# 10-14                26   Lirtossa84   11   Male       71
# 15-19                30       Idai61   19   Male      140
# 20-24                 0      Lisim78   20   Male      108
# 25-29                25    Lisirra87   29   Male      178
# 30-34                19    Chamalo71   30   Male       89
# 35-39                 6    Itheria73   36   Male      169
# 40+                   1  Lisovynya38   40   Male      143
#
#                                                Item Name  Price
# Age Ranges
# <10                          Blood-Forged Skeletal Spine   3.09
# 10-14                                             Demise   1.61
# 15-19                                            Striker   2.94
# 20-24          Extraction, Quickblade Of Trembling Hands   3.53
# 25-29       Oathbreaker, Last Hope of the Breaking Storm   4.23
# ...

# %%
purchase_count_age
# Out:
# Age Ranges
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: Purchase ID, dtype: int64

# %%
avg_count_age = purchase_data_grouped["Price"].mean()
avg_count_age
# Out:
# Age Ranges
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.941538
# Name: Price, dtype: float64

# %%
tot_count_age = purchase_data_grouped["Price"].sum()
tot_count_age
# Out:
# Age Ranges
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64

# %%
avg_tot_purch_count_age = tot_count_age/purchase_data_grouped['SN'].nunique()
avg_tot_purch_count_age
# Out:
# Age Ranges
# <10      4.537059
# 10-14    3.762727
# 15-19    3.858785
# 20-24    4.318062
# 25-29    3.805195
# 30-34    4.115385
# 35-39    4.763548
# 40+      3.186667
# dtype: float64

# %%
purch_analysis_age = pd.DataFrame({"Purchase Count":purchase_count_age,
                                   "Average Purchase Price":avg_count_age, 
                                   "Total Purchase Value":tot_count_age, 
                                   "Avg Total Purchase per Person":avg_tot_purch_count_age})
purch_analysis_age
# Out:
#             Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Ranges
# <10                     23                3.353478                 77.13
# 10-14                   28                2.956429                 82.78
# 15-19                  136                3.035956                412.89
# 20-24                  365                3.052219               1114.06
# 25-29                  101                2.900990                293.00
# 30-34                   73                2.931507                214.00
# 35-39                   41                3.601707                147.67
# 40+                     13                2.941538                 38.24
#
#             Avg Total Purchase per Person
# Age Ranges
# <10                              4.537059
# 10-14                            3.762727
# 15-19                            3.858785
# 20-24                            4.318062
# 25-29                            3.805195
# ...

# %%
purch_analysis_age["Average Purchase Price"] = purch_analysis_age["Average Purchase Price"].map("${:.2f}".format)
purch_analysis_age["Total Purchase Value"] = purch_analysis_age["Total Purchase Value"].map("${:.2f}".format)
purch_analysis_age["Avg Total Purchase per Person"] = purch_analysis_age["Avg Total Purchase per Person"].map("${:.2f}".format)
purch_analysis_age
# Out:
#             Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                     23                  $3.35               $77.13
# 10-14                   28                  $2.96               $82.78
# 15-19                  136                  $3.04              $412.89
# 20-24                  365                  $3.05             $1114.06
# 25-29                  101                  $2.90              $293.00
# 30-34                   73                  $2.93              $214.00
# 35-39                   41                  $3.60              $147.67
# 40+                     13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
spender_data = purchase_data
spender_data_top = spender_data.groupby("SN")
spender_data_top.first()
# Out:
#                Purchase ID  Age  Gender  Item ID  \
# SN
# Adairialis76           467   16    Male      123
# Adastirin33            142   35  Female      175
# Aeda94                 388   17    Male      128
# Aela59                  28   21    Male      119
# Aelaria33              630   23    Male      171
# ...                    ...  ...     ...      ...
# Yathecal82             125   20  Female       62
# Yathedeu43              93   22    Male       88
# Yoishirrala98          572   17  Female      145
# Zhisrisu83              54   10    Male       25
# Zontibe81               17   21    Male      161
#
#                                                Item Name  Price Age Ranges
# SN
# Adairialis76                           Twilight's Carver   2.28      15-19
# Adastirin33                   Woeful Adamantite Claymore   4.48      35-39
# Aeda94                     Blazeguard, Reach of Eternity   4.91      15-19
# ...

# %%
spenders_name = spender_data_top['SN'].nunique()
spenders_name
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       1
# Yathedeu43       1
# Yoishirrala98    1
# Zhisrisu83       1
# Zontibe81        1
# Name: SN, Length: 576, dtype: int64

# %%
spenders_count = spender_data_top['Purchase ID'].count()
spenders_count
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       3
# Yathedeu43       2
# Yoishirrala98    1
# Zhisrisu83       2
# Zontibe81        3
# Name: Purchase ID, Length: 576, dtype: int64

# %%
spenders_average = spender_data_top['Price'].mean()
spenders_average
# Out:
# SN
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Name: Price, Length: 576, dtype: float64

# %%
spenders_total = spender_data_top['Price'].sum()
spenders_total
# Out:
# SN
# Adairialis76     2.28
# Adastirin33      4.48
# Aeda94           4.91
# Aela59           4.32
# Aelaria33        1.79
#                  ...
# Yathecal82       6.22
# Yathedeu43       6.02
# Yoishirrala98    4.58
# Zhisrisu83       7.89
# Zontibe81        8.03
# Name: Price, Length: 576, dtype: float64

# %%
spend_data = pd.DataFrame({"Purchase Count":spenders_count, 
                           "Average Purchase Price":spenders_average, 
                           "Total Purchase Value":spenders_total})
spend_data
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                1                2.280000                  2.28
# Adastirin33                 1                4.480000                  4.48
# Aeda94                      1                4.910000                  4.91
# Aela59                      1                4.320000                  4.32
# Aelaria33                   1                1.790000                  1.79
# ...                       ...                     ...                   ...
# Yathecal82                  3                2.073333                  6.22
# Yathedeu43                  2                3.010000                  6.02
# Yoishirrala98               1                4.580000                  4.58
# Zhisrisu83                  2                3.945000                  7.89
# Zontibe81                   3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
spend_data_sort = spend_data.sort_values("Total Purchase Value",ascending=False)
spend_data_sort.head(5)
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
spend_data_sort["Average Purchase Price"] = spend_data_sort["Average Purchase Price"].map("${:.2f}".format)
spend_data_sort["Total Purchase Value"] = spend_data_sort["Total Purchase Value"].map("${:.2f}".format)
spend_data_sort.head(5)
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_data = purchase_data

# %%
popular_data2 = popular_data.replace(101,92)
popular_data3 = popular_data2.replace(141,132)
popular_data3
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Ranges
# 0    Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                            Frenzied Scimitar   1.56        40+
# 2                                 Final Critic   4.88      20-24
# ...

# %%
pop_data_top = popular_data3.groupby(["Item ID","Item Name"])
pop_data_top.first()
# Out:
#                                          Purchase ID           SN  Age  \
# Item ID Item Name
# 0       Splinter                                 133     Phaena87   20
# 1       Crucifer                                 121     Ilosia37   23
# 2       Verdict                                  134     Phyali88   15
# 3       Phantomlight                             161        Iri67   20
# 4       Bloodlord's Fetish                        13  Assjaskan73   22
# ...                                              ...          ...  ...
# 179     Wolf, Promise of the Moonwalker           31  Farusrian86   37
# 180     Stormcaller                              751  Lisjaskan36   11
# 181     Reaper's Toll                             45    Haerith37   23
# 182     Toothpick                                256   Chamirra53   23
# 183     Dragon's Greatsword                      165   Lirtassa52   15
#
#                                          Gender  Price Age Ranges
# Item ID Item Name
# ...

# %%
pop_data_count = pop_data_top['Item Name'].count()
pop_data_count
# Out:
# Item ID  Item Name
# 0        Splinter                           4
# 1        Crucifer                           3
# 2        Verdict                            6
# 3        Phantomlight                       6
# 4        Bloodlord's Fetish                 5
#                                            ..
# 179      Wolf, Promise of the Moonwalker    6
# 180      Stormcaller                        1
# 181      Reaper's Toll                      5
# 182      Toothpick                          3
# 183      Dragon's Greatsword                3
# Name: Item Name, Length: 181, dtype: int64

# %%
pop_data_price = pop_data_top['Price'].mean()
pop_data_price
# Out:
# Item ID  Item Name
# 0        Splinter                           1.28
# 1        Crucifer                           3.26
# 2        Verdict                            2.48
# 3        Phantomlight                       2.49
# 4        Bloodlord's Fetish                 1.70
#                                             ...
# 179      Wolf, Promise of the Moonwalker    4.48
# 180      Stormcaller                        3.36
# 181      Reaper's Toll                      1.66
# 182      Toothpick                          4.03
# 183      Dragon's Greatsword                1.09
# Name: Price, Length: 181, dtype: float64

# %%
pop_data_price_total = pop_data_top['Price'].sum()
pop_data_price_total
# Out:
# Item ID  Item Name
# 0        Splinter                            5.12
# 1        Crucifer                            9.78
# 2        Verdict                            14.88
# 3        Phantomlight                       14.94
# 4        Bloodlord's Fetish                  8.50
#                                             ...
# 179      Wolf, Promise of the Moonwalker    26.88
# 180      Stormcaller                         3.36
# 181      Reaper's Toll                       8.30
# 182      Toothpick                          12.09
# 183      Dragon's Greatsword                 3.27
# Name: Price, Length: 181, dtype: float64

# %%
pop_data_summary = pd.DataFrame({"Purchase Count":pop_data_count, 
                           "Item Price":pop_data_price, 
                           "Total Purchase Value":pop_data_price_total})
pop_data_summary.head()
# Out:
#                             Purchase Count  Item Price  Total Purchase Value
# Item ID Item Name
# 0       Splinter                         4        1.28                  5.12
# 1       Crucifer                         3        3.26                  9.78
# 2       Verdict                          6        2.48                 14.88
# 3       Phantomlight                     6        2.49                 14.94
# 4       Bloodlord's Fetish               5        1.70                  8.50

# %%
pop_data_sum_top = pop_data_summary.sort_values("Purchase Count",ascending=False)
pop_data_sum_top.head(6)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 132     Persuasion                                                 9
# 145     Fiery Glass Crusader                                       9
# 82      Nirvana                                                    9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 132     Persuasion                                      3.221111
# 145     Fiery Glass Crusader                            4.580000
# 82      Nirvana                                         4.900000
# ...

# %%
pop_data_sum_top["Item Price"] = pop_data_sum_top["Item Price"].map("${:.2f}".format)
pop_data_sum_top["Total Purchase Value"] = pop_data_sum_top["Total Purchase Value"].map("${:.2f}".format)
pop_data_sum_top.head(6)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 132     Persuasion                                                 9
# 145     Fiery Glass Crusader                                       9
# 82      Nirvana                                                    9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 132     Persuasion                                        $3.22
# 145     Fiery Glass Crusader                              $4.58
# 82      Nirvana                                           $4.90
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
pop_data_sum_value = pop_data_summary.sort_values("Total Purchase Value",ascending=False)
pop_data_sum_value.head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
pop_data_sum_value["Item Price"] = pop_data_sum_value["Item Price"].map("${:.2f}".format)
pop_data_sum_value["Total Purchase Value"] = pop_data_sum_value["Total Purchase Value"].map("${:.2f}".format)
pop_data_sum_value.head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
